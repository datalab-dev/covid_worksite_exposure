# %%
# Import libraries
import geopandas as gpd
import pandas as pd
import numpy as np
from google.colab import drive
from pathlib import Path
import sys
import os
import requests
import requests_cache
import time

# Set up request caching
requests_cache.install_cache('covid_exposure_match_unnamed_buildings')

# %%
drive.mount('/content/drive', force_remount = True)

# Set base path
base = Path('/content/drive/MyDrive/covid_exposure')
sys.path.append(str(base))
path = '/content/drive/MyDrive/covid_exposure/UC_Davis_Building_Footprints_2024-02-09.geojson'
# Out:
# Mounted at /content/drive

# %%
# Load files
footprints = gpd.read_file(path)
building_dict = pd.read_csv('/content/drive/MyDrive/covid_exposure/building_dictionary.csv', sep=",")
unmatched_building = pd.read_csv('/content/drive/MyDrive/covid_exposure/unmatched_buildings.csv', encoding='latin-1')

# %%
unmatched_building = unmatched_building[['campus_building', 'worksite', 'location']]
unmatched_series = unmatched_building['campus_building'].drop_duplicates()
unmatched_build = pd.DataFrame({"campus_building": unmatched_series})

# %%
# get important columns and drop NAs
footprints_coord = footprints.dropna(subset=['FullBldgNa'])[['FullBldgNa', 'LatY', 'LongX']]

# %% [markdown]
# # Google API
#
# Google Maps API to get address (lat, long) of unmatched buildings -> match lat, long of footprint within a set radius -> Add FullBldgNa (footprints) to target + campus_building (unmatched_series) to building_dict -> Order bulding_dict

# %%
import googlemaps

# %%
google_api_key = 'INSERT_API_KEY'

# Initialize Google Maps Client
gmaps = googlemaps.Client(key=google_api_key)

# %%
#test
#test = unmatched_build[0:25]
#geocode_result = gmaps.geocode('Walter A. Robinson Welcome Center' + ' Davis CA US')
# Out:
# [{'address_components': [{'long_name': '550',
#     'short_name': '550',
#     'types': ['street_number']},
#    {'long_name': 'Alumni Lane', 'short_name': 'Alumni Ln', 'types': ['route']},
#    {'long_name': 'Davis',
#     'short_name': 'Davis',
#     'types': ['locality', 'political']},
#    {'long_name': 'Yolo County',
#     'short_name': 'Yolo County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'California',
#     'short_name': 'CA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '95616', 'short_name': '95616', 'types': ['postal_code']}],
#   'formatted_address': '550 Alumni Ln, Davis, CA 95616, USA',
#   'geometry': {'location': {'lat': 38.5345563, 'lng': -121.7473162},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 38.5358663302915,
#      'lng': -121.7461258697085},
#     'southwest': {'lat': 38.5331683697085, 'lng': -121.7488238302915}}},
#   'partial_match': True,
#   'place_id': 'ChIJ601lzxMphYARPPlgTkANlu0',
#   'plus_code': {'compound_code': 'G7M3+R3 Davis, CA',
#    'global_code': '84CWG7M3+R3'},
#   'types': ['establishment', 'point_of_interest', 'travel_agency']}]

# %%
for index, row in unmatched_build.iterrows():
    print(index, row)

    # Geocode the address
    geocode_result = gmaps.geocode(row['campus_building'] + ' Davis CA US')

    # Check if result is found
    if geocode_result:
        # Extract latitude and longitude and assign to DataFrame
        unmatched_build.loc[index, 'lat'] = geocode_result[0]['geometry']['location']['lat']
        unmatched_build.loc[index, 'long'] = geocode_result[0]['geometry']['location']['lng']
    else:
        # Handle case where result is not found
        print("Geocode result not found for address:", row['campus_building'])
# Out:
# 0 campus_building    Scrubs Café
# Name: 0, dtype: object
# 3 campus_building    100 Dairy Road
# Name: 3, dtype: object
# 4 campus_building    1000 Old Davis Road
# Name: 4, dtype: object
# 5 campus_building    112 A Street
# Name: 5, dtype: object
# 6 campus_building    1333 Research Park Drive
# Name: 6, dtype: object
# 10 campus_building    1441 Research Park Drive
# Name: 10, dtype: object
# 14 campus_building    1450 Drew Avenue
# Name: 14, dtype: object
# 15 campus_building    1450 Drew Circle
# Name: 15, dtype: object
# 16 campus_building    1515 Newton Court
# Name: 16, dtype: object
# 20 campus_building    1544 Newton Court
# Name: 20, dtype: object
# 29 campus_building    1605 Tilia Street
# Name: 29, dtype: object
# 33 campus_building    1632 Da Vinci Court
# Name: 33, dtype: object
# 34 campus_building    1632 Davinci Court
# Name: 34, dtype: object
# 35 campus_building    1815 Research Park
# Name: 35, dtype: object
# 36 campus_building    1850 Research Park Drive
# Name: 36, dtype: object
# 72 campus_building    202 Cousteau Place
# Name: 72, dtype: object
# 268 campus_building    205 Cousteau Place
# Name: 268, dtype: object
# 269 campus_building    267 Cousteau Place
# Name: 269, dtype: object
# 278 campus_building    2795 2nd Street
# Name: 278, dtype: object
# 287 campus_building    2828 Cowell Blvd
# Name: 287, dtype: object
# 288 campus_building    298 Horizon Street
# Name: 288, dtype: object
# 289 campus_building    301 Orchard Park Drive
# Name: 289, dtype: object
# 290 campus_building    311 Collier Way, Etna, CA
# Name: 290, dtype: object
# 291 campus_building    359 North Sage St.,The Green
# Name: 291, dtype: object
# 292 campus_building    400 Hopkins Road
# Name: 292, dtype: object
# 293 campus_building    607 Pena Drive
# Name: 293, dtype: object
# 294 campus_building    615 Hopkins Road
# Name: 294, dtype: object
# 295 campus_building    650 La Rue Road
# Name: 295, dtype: object
# 296 campus_building    740 La Rue Road
# Name: 296, dtype: object
# 297 campus_building    8-4
# Name: 297, dtype: object
# 298 campus_building    Activities & Recreation Center - Conference Ce...
# Name: 298, dtype: object
# 299 campus_building    Agricultural Field Station
# Name: 299, dtype: object
# 300 campus_building    Agronomy Field Headquarters
# Name: 300, dtype: object
# 301 campus_building    AHMCT Research Center
# Name: 301, dtype: object
# 302 campus_building    Air Quality Research Center
# Name: 302, dtype: object
# 303 campus_building    Air Quality Research Center (Drew Ave)
# Name: 303, dtype: object
# 304 campus_building    Alhambra Cannery
# Name: 304, dtype: object
# 305 campus_building    Alumni Center, Walter A. Buehler
# Name: 305, dtype: object
# 306 campus_building    Animal Resource Service
# Name: 306, dtype: object
# 308 campus_building    Animal Resource Service Building
# Name: 308, dtype: object
# 309 campus_building    Animal Sciences
# Name: 309, dtype: object
# 310 campus_building    Antenna Farm
# Name: 310, dtype: object
# 311 campus_building    Bob Foster Team Center
# Name: 311, dtype: object
# 312 campus_building    Bodega Marine Laboratory
# Name: 312, dtype: object
# 393 campus_building    Botanical Conservatory
# Name: 393, dtype: object
# 394 campus_building    Bowley Hall
# Name: 394, dtype: object
# 395 campus_building    Brewery & Food Science Building
# Name: 395, dtype: object
# 396 campus_building    Brewery, Winery, and Food Pilot Facility
# Name: 396, dtype: object
# 397 campus_building    Bruce Edwards Club Room
# Name: 397, dtype: object
# 398 campus_building    Bruce Edwards Club Room / Stadium
# Name: 398, dtype: object
# 402 campus_building    CA Animal Health & Food Safety - San Bernardino
# Name: 402, dtype: object
# 411 campus_building    CA Animal Health & Food Safety Lab - Tulare
# Name: 411, dtype: object
# 412 campus_building    CA Animal Health & Food Safety Laboratory
# Name: 412, dtype: object
# 413 campus_building    CA Animal Health and Food Safety Lab, Turlock
# Name: 413, dtype: object
# 414 campus_building    CAHFS-Turlock Laboratory
# Name: 414, dtype: object
# 415 campus_building    CAHFS San Bernardino Lab
# Name: 415, dtype: object
# 416 campus_building    Calif Animal Health & Food Safety, San Bernardino
# Name: 416, dtype: object
# 417 campus_building    Calif. Animal Health & Food Safety Lab - Tulare
# Name: 417, dtype: object
# 418 campus_building    Calif. Animal Health & Food Safety, San Bernar...
# Name: 418, dtype: object
# 419 campus_building    California Animal Health & Food Safety
# Name: 419, dtype: object
# 428 campus_building    California Animal Health & Food Safety - Tulare
# Name: 428, dtype: object
# 432 campus_building    California Animal Health & Food Safety - Turlock
# Name: 432, dtype: object
# 436 campus_building    California Animal Health & Food Safety Lab
# Name: 436, dtype: object
# 440 campus_building    California Animal Health & Food Safety Lab System
# Name: 440, dtype: object
# 441 campus_building    California Animal Health & Food Safety Lab, Tu...
# Name: 441, dtype: object
# 450 campus_building    California Animal Health & Food Safety, Tulare
# Name: 450, dtype: object
# 451 campus_building    California Animal Health and Food Safety
# Name: 451, dtype: object
# 455 campus_building    California Lighting Technology Center
# Name: 455, dtype: object
# 456 campus_building    California National Research Primate Center
# Name: 456, dtype: object
# 457 campus_building    Campus Veterinary Services - H3 Building
# Name: 457, dtype: object
# 458 campus_building    Center for Aquatic Biology and Aquaculture
# Name: 458, dtype: object
# 467 campus_building    Center For Aquatic Biology and Aquaculture
# Name: 467, dtype: object
# 468 campus_building    Center for Child & Family Studies
# Name: 468, dtype: object
# 472 campus_building    Center for Child and Family Studies
# Name: 472, dtype: object
# 473 campus_building    Center for Geotechnical Modeling
# Name: 473, dtype: object
# 477 campus_building    Central Receiving
# Name: 477, dtype: object
# 478 campus_building    Cole Building
# Name: 478, dtype: object
# 479 campus_building    Communication Resources Building
# Name: 479, dtype: object
# 483 campus_building    Communications Building
# Name: 483, dtype: object
# 484 campus_building    Continuing and Professional Education - Sacram...
# Name: 484, dtype: object
# 488 campus_building    Cuarto Building
# Name: 488, dtype: object
# 489 campus_building    Cuarto Residence Halls
# Name: 489, dtype: object
# 490 campus_building    Custodial  Services
# Name: 490, dtype: object
# 491 campus_building    Da Vinci Court
# Name: 491, dtype: object
# 492 campus_building    Design & Construction Management
# Name: 492, dtype: object
# 493 campus_building    Dutton Hall, Room 1200
# Name: 493, dtype: object
# 494 campus_building    Earth & Physical Sciences Building
# Name: 494, dtype: object
# 510 campus_building    Earth & Planetary Sciences
# Name: 510, dtype: object
# 511 campus_building    Earth and Planetary Sciences
# Name: 511, dtype: object
# 512 campus_building    Earth and Planetary Sciences Department
# Name: 512, dtype: object
# 513 campus_building    Education Building
# Name: 513, dtype: object
# 514 campus_building    Educational Opportunity Center Building
# Name: 514, dtype: object
# 515 campus_building    Edwards Family Athletics Center
# Name: 515, dtype: object
# 524 campus_building    Energy Conservation Center
# Name: 524, dtype: object
# 525 campus_building    Environmental Services Facility
# Name: 525, dtype: object
# 550 campus_building    Facilities Maintenance
# Name: 550, dtype: object
# 551 campus_building    Facilities Maintenance Building
# Name: 551, dtype: object
# 567 campus_building    Facilities Management
# Name: 567, dtype: object
# 583 campus_building    Facilities Management Building
# Name: 583, dtype: object
# 592 campus_building    Facilities Services Building
# Name: 592, dtype: object
# 617 campus_building    Facilities Steam Shop
# Name: 617, dtype: object
# 618 campus_building    Fish Conservation and Culture Laboratory (FCCL)
# Name: 618, dtype: object
# 619 campus_building    Fleet Services Building
# Name: 619, dtype: object
# 620 campus_building    Fleet Services Central Carage Campus
# Name: 620, dtype: object
# 629 campus_building    Foundation Plant Sciences
# Name: 629, dtype: object
# 630 campus_building    Foundation Plant Services
# Name: 630, dtype: object
# 634 campus_building    Foundation Plant Services Facility
# Name: 634, dtype: object
# 638 campus_building    Freeborn Hall - Lower
# Name: 638, dtype: object
# 639 campus_building    Freeborn Hall, Lower
# Name: 639, dtype: object
# 640 campus_building    Gallager Hall
# Name: 640, dtype: object
# 641 campus_building    Genome & Biological Sciences Facility
# Name: 641, dtype: object
# 642 campus_building    Genome & Biomedical Sciences Building
# Name: 642, dtype: object
# 643 campus_building    Gourley Building
# Name: 643, dtype: object
# 644 campus_building    Gourley Hall
# Name: 644, dtype: object
# 645 campus_building    Government and Community Relations
# Name: 645, dtype: object
# 646 campus_building    Granite Canyon Laboratory, Monterey, CA
# Name: 646, dtype: object
# 647 campus_building    Grounds
# Name: 647, dtype: object
# 648 campus_building    Grounds and Landscape Services Office
# Name: 648, dtype: object
# 649 campus_building    Health Stadium Press Box
# Name: 649, dtype: object
# 653 campus_building    Hopkins Services Complex
# Name: 653, dtype: object
# 657 campus_building    Housing Admin Building
# Name: 657, dtype: object
# 658 campus_building    Hydraulics Lab
# Name: 658, dtype: object
# 659 campus_building    IACUC Trailer
# Name: 659, dtype: object
# 660 campus_building    Imagining America Office
# Name: 660, dtype: object
# 661 campus_building    Indio Hall
# Name: 661, dtype: object
# 662 campus_building    Institute of Toxicology & Environmental Health
# Name: 662, dtype: object
# 663 campus_building    Institute of Transportation Studies
# Name: 663, dtype: object
# 664 campus_building    Intercollegiate Athletics
# Name: 664, dtype: object
# 665 campus_building    Internal Audit Services
# Name: 665, dtype: object
# 666 campus_building    International Building
# Name: 666, dtype: object
# 670 campus_building    John E. Thurman Jr. Laboratory Building
# Name: 670, dtype: object
# 671 campus_building    John E. Thurman, Jr. Laboratory
# Name: 671, dtype: object
# 672 campus_building    Katherine Esau Hall
# Name: 672, dtype: object
# 673 campus_building    Katherine Esau Science Hall
# Name: 673, dtype: object
# 677 campus_building    Kenneth L. Maddy Laboratory
# Name: 677, dtype: object
# 681 campus_building    Kenneth L. Maddy Laboratory Building
# Name: 681, dtype: object
# 682 campus_building    Kenneth Maddy Lab
# Name: 682, dtype: object
# 683 campus_building    Latitude Market
# Name: 683, dtype: object
# 684 campus_building    LGBTQIA Resource Center
# Name: 684, dtype: object
# 685 campus_building    Life Sciences Building, 2163
# Name: 685, dtype: object
# 686 campus_building    Maddy Laboratory
# Name: 686, dtype: object
# 687 campus_building    Math Sciences Building
# Name: 687, dtype: object
# 688 campus_building    Meat Laboratory, Cole Facility Building C
# Name: 688, dtype: object
# 689 campus_building    Med Sciences 1B
# Name: 689, dtype: object
# 690 campus_building    Medical Sciences 1 C
# Name: 690, dtype: object
# 691 campus_building    Memorial Union Game Center
# Name: 691, dtype: object
# 692 campus_building    Memorial Union Gaming Center
# Name: 692, dtype: object
# 693 campus_building    MIND Institute
# Name: 693, dtype: object
# 694 campus_building    Mondavi Center Admin Building
# Name: 694, dtype: object
# 695 campus_building    MU Coffee House
# Name: 695, dtype: object
# 696 campus_building    MU Game Center
# Name: 696, dtype: object
# 697 campus_building    Multi-Purpose Teaching
# Name: 697, dtype: object
# 698 campus_building    One Capitol Mall, Sacramento
# Name: 698, dtype: object
# 699 campus_building    Physical Sciences Library
# Name: 699, dtype: object
# 700 campus_building    Plant Sciences Building
# Name: 700, dtype: object
# 701 campus_building    Plumbing & Steam
# Name: 701, dtype: object
# 702 campus_building    Primero Grove
# Name: 702, dtype: object
# 703 campus_building    Rec Pool / Recreation Pool
# Name: 703, dtype: object
# 707 campus_building    Regan Hall
# Name: 707, dtype: object
# 708 campus_building    Repro Graphics (West Sacramento)
# Name: 708, dtype: object
# 709 campus_building    Research Park
# Name: 709, dtype: object
# 710 campus_building    RMI North Building
# Name: 710, dtype: object
# 711 campus_building    Robert Mondavi Institute North
# Name: 711, dtype: object
# 712 campus_building    Robert Mondavi Institute North Building
# Name: 712, dtype: object
# 713 campus_building    Robert Mondavi Institute South
# Name: 713, dtype: object
# 714 campus_building    Russell Field
# Name: 714, dtype: object
# 715 campus_building    Sage St. Market
# Name: 715, dtype: object
# 716 campus_building    San Bernardino Lab
# Name: 716, dtype: object
# 720 campus_building    Schaal Aquatics Center
# Name: 720, dtype: object
# 721 campus_building    Science Lab Building
# Name: 721, dtype: object
# 722 campus_building    Scrub Oak Hall (Auditorium)
# Name: 722, dtype: object
# 723 campus_building    Segundo Housing and Dining Services
# Name: 723, dtype: object
# 724 campus_building    Segundo Student Housing & Dining Services
# Name: 724, dtype: object
# 725 campus_building    Services for International Students and Scholars
# Name: 725, dtype: object
# 726 campus_building    Social Science and Humanities
# Name: 726, dtype: object
# 727 campus_building    Solano Park - Office
# Name: 727, dtype: object
# 728 campus_building    South Silo
# Name: 728, dtype: object
# 729 campus_building    Sprocket Hall
# Name: 729, dtype: object
# 730 campus_building    Stadium: Bruce Edwards Club Room
# Name: 730, dtype: object
# 734 campus_building    Student Community Center Coffee House
# Name: 734, dtype: object
# 735 campus_building    Student Dining and Housing Services - Tercero
# Name: 735, dtype: object
# 736 campus_building    Student Housing
# Name: 736, dtype: object
# 737 campus_building    Student Housing Admin Building
# Name: 737, dtype: object
# 741 campus_building    Student Housing and Dining Services
# Name: 741, dtype: object
# 745 campus_building    Student Housing/Dining
# Name: 745, dtype: object
# 746 campus_building    Student Recruitment & Retention Center
# Name: 746, dtype: object
# 747 campus_building    Supply Chain Management
# Name: 747, dtype: object
# 748 campus_building    Tahoe Environmental Research Center
# Name: 748, dtype: object
# 749 campus_building    TANA arts facility, 1224 Lemen Av, Woodland
# Name: 749, dtype: object
# 750 campus_building    TB-1
# Name: 750, dtype: object
# 751 campus_building    Teaching & Research Animal Care Services
# Name: 751, dtype: object
# 755 campus_building    Teaching and Research Animal Care Services
# Name: 755, dtype: object
# 759 campus_building    Teaching and Research Animal Care Services (TR...
# Name: 759, dtype: object
# 760 campus_building    Temporary Building 2
# Name: 760, dtype: object
# 761 campus_building    Tercero North
# Name: 761, dtype: object
# 762 campus_building    Tercero Student Housing & Dining Services
# Name: 762, dtype: object
# 763 campus_building    TES Building
# Name: 763, dtype: object
# 764 campus_building    Ticon II
# Name: 764, dtype: object
# 765 campus_building    Transportation & Parking Services
# Name: 765, dtype: object
# 766 campus_building    Trinchero Family Estates Building
# Name: 766, dtype: object
# 767 campus_building    Tulare Lab
# Name: 767, dtype: object
# 768 campus_building    UC Center Sacramento
# Name: 768, dtype: object
# 769 campus_building    UC Davis Bodega Marine Laboratory
# Name: 769, dtype: object
# 770 campus_building    UC Davis Campus Clinic
# Name: 770, dtype: object
# 771 campus_building    UC Davis Fire & Police Station
# Name: 771, dtype: object
# 772 campus_building    UC Davis Police & Fire
# Name: 772, dtype: object
# 773 campus_building    UC Davis Police Annex
# Name: 773, dtype: object
# 774 campus_building    UC Davis School of Veterinary Medicine
# Name: 774, dtype: object
# 775 campus_building    UCU Center
# Name: 775, dtype: object
# 776 campus_building    Unitrans Facility
# Name: 776, dtype: object
# 777 campus_building    Unitrans Facility Maintenance Building
# Name: 777, dtype: object
# 778 campus_building    University Center
# Name: 778, dtype: object
# 779 campus_building    University Services Building/1441 Research Park
# Name: 779, dtype: object
# 780 campus_building    Upward Bound - Siskiyou Office
# Name: 780, dtype: object
# 781 campus_building    Utilities Division
# Name: 781, dtype: object
# 782 campus_building    Vegetable Crop Greenhouse
# Name: 782, dtype: object
# 783 campus_building    Vet Med-Tulare
# Name: 783, dtype: object
# 784 campus_building    Vet Med Multi-Purpose Teaching Facility
# Name: 784, dtype: object
# 785 campus_building    Vet Med Teaching & Research Center, Tulare
# Name: 785, dtype: object
# 786 campus_building    Vet Med Teaching Facility
# Name: 786, dtype: object
# 787 campus_building    Vet Med Teaching Hospital - Small Animal Clinic
# Name: 787, dtype: object
# 788 campus_building    Vet Med Teaching Hospital B Barn
# Name: 788, dtype: object
# 789 campus_building    Vet Med Teaching Hospital C Barn
# Name: 789, dtype: object
# 790 campus_building    Vet Met Teaching Hospital
# Name: 790, dtype: object
# 791 campus_building    Veterinary Genetics Lab
# Name: 791, dtype: object
# 800 campus_building    Veterinary Genetics Laboratory
# Name: 800, dtype: object
# 809 campus_building    Veterinary Medecine 2
# Name: 809, dtype: object
# 810 campus_building    Veterinary Medicine MPT
# Name: 810, dtype: object
# 811 campus_building    Veterinary Medicine Teaching Hospital
# Name: 811, dtype: object
# 836 campus_building    Veterinary Medicine VM3A
# Name: 836, dtype: object
# 837 campus_building    Veterinary Small Animal Clinic
# Name: 837, dtype: object
# 838 campus_building    Walter A. Robinson Welcome Center
# Name: 838, dtype: object
# 839 campus_building    Wastewater Treatment Plant Administration Buil...
# Name: 839, dtype: object
# 840 campus_building    West Village - 1715 Tilia Street
# Name: 840, dtype: object
# 841 campus_building    West Village 215 Sage Street
# Name: 841, dtype: object
# 842 campus_building    West Village Square & Community College
# Name: 842, dtype: object
# 843 campus_building    Western Cooling Efficiency Center
# Name: 843, dtype: object
# 844 campus_building    Wyatt Pavilion Theatre
# Name: 844, dtype: object

# %% [markdown]
# # Sklearn BallTree algorithm
#
# * Unsupervised nearest neighbor: output the nearest building in the UC Davis Footprint within a 30 meter radius using the Harvestine metric
# * Harvestine metric: based on a sphere
# * Sklearn only supports radians - need to convert lat/long coordinates
# * https://scikit-learn.org/stable/modules/neighbors.html

# %%
from sklearn.neighbors import BallTree

# sklearn require radians
footprints_radians = np.radians(footprints_coord[["LatY", "LongX"]].values)

# Build BallTree for UC Davis building footprints
tree = BallTree(footprints_radians, metric='haversine')

# %%
# Convert distance to radians
test_radius = 30 # meters
earth_radius = 6371000 # meters
radius = test_radius / earth_radius

# %%
# Unmatched coord
locations_radians = np.radians(unmatched_build[["lat", "long"]].values)

# %%
# Query nearest neighbors within the radius for each building
ind, results = tree.query_radius(X = locations_radians, r=radius, return_distance=True)

# %%
#print(ind)
#print(results * earth_radius)

# %%
# Initialize a list to store the results
results_list = []

# Iterate over each query result
for index, (indices, distances) in enumerate(zip(ind, results)):
    if len(indices) > 0:

        # find index of the closest building
        closest_building_index = indices[0]

        # calculate distance to the closest building
        closest_building_distance = distances[0] * earth_radius

        # get name of the closest building from footprints
        closest_building_name = footprints_coord['FullBldgNa'].iloc[closest_building_index]

        # get name of the unmatched campus building
        unmatched_building_name = unmatched_build.iloc[index]['campus_building']

        # Append results to the list
        results_list.append({'target': closest_building_name,
                             'variation': unmatched_building_name,
                             'distance': closest_building_distance})
    else:
        # when no neighbors are found within the radius
        unmatched_building_name = unmatched_build.iloc[index]['campus_building']
        results_list.append({'target': None,
                             'variation': unmatched_building_name,
                             'distance': None})

# convert list of dictionaries into a df
results_df = pd.DataFrame(results_list)
results_df
# Out:
#                                  target  \
# 0                           Scrubs Cafe
# 1                                  None
# 2            Animal Resource Service R2
# 3                    Davis 116 A Street
# 4          Administrative Services West
# ..                                  ...
# 233  West Village Sol 110 A Sage Street
# 234  West Village Sol 110 A Sage Street
# 235                                None
# 236    West Village Sol 215 Sage Street
# 237      Fred S. Wyatt Pavilion Theatre
#
#                                    variation   distance
# 0                                Scrubs Café  12.051592
# 1                             100 Dairy Road        NaN
# 2                        1000 Old Davis Road  28.222169
# 3                               112 A Street  16.091604
# 4                   1333 Research Park Drive  21.766394
# ..                                       ...        ...
# 233         West Village - 1715 Tilia Street   5.979258
# 234             West Village 215 Sage Street   5.979258
# 235  West Village Square & Community College        NaN
# 236        Western Cooling Efficiency Center   6.047015
# 237                   Wyatt Pavilion Theatre   6.291684
#
# [238 rows x 3 columns]

# %%
print("Manual input:", results_df['distance'].isnull().sum(), ", Percentage:", results_df['distance'].isnull().sum()/results_df.shape[0])
# Out:
# Manual input: 128 , Percentage: 0.5378151260504201

# %%
# test
footprints[footprints["StreetAddr"].fillna("").str.contains("Alumni")][['LatY', 'LongX']]
# 38.5345563, 'lng': -121.7473162
# Out:
#            LatY       LongX
# 1131  38.535195 -121.748216
# 1293  38.534811 -121.747233
# 1306  38.534535 -121.746942

# %% [markdown]
# # Append target, variation into building_dictionary.csv
#
# * Append
# * Order in ascending order
# * Add unmatched buildings with "", variation for manual input

# %%
# append
final_building_dict = pd.concat([building_dict, results_df[['target', 'variation']]]) # .append() method depreciated
final_building_dict = final_building_dict.sort_values(by = 'target')
final_building_dict
# Out:
#                                target                                variation
# 0                        260 Cousteau                       260 Cousteau Place
# 1             Academic Surge Building                           Academic Surge
# 2             Academic Surge Building                 Academic Surge HRVIP Lab
# 9    Activities and Recreation Center           Activities Recreation & Center
# 7    Activities and Recreation Center                                      ARC
# ..                                ...                                      ...
# 227                              None                  Veterinary Medicine MPT
# 228                              None    Veterinary Medicine Teaching Hospital
# 229                              None                 Veterinary Medicine VM3A
# 230                              None           Veterinary Small Animal Clinic
# 235                              None  West Village Square & Community College
#
# [518 rows x 2 columns]

# %%
# export building_dict.csv into drive
final_building_dict.to_csv('/content/drive/MyDrive/covid_exposure/building_dictionary_1.csv', index=False)

# export unmatched_build into drive
# so API doesn't have to be run again
unmatched_build.to_csv('/content/drive/MyDrive/covid_exposure/unmatched_building_coordinates.csv', index=False)
